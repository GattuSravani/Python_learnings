# %%
def name_0():
    print('Hello I am sravani')

# %%
def name_1():
    return "Hellp I am sravani"

# %%
f0 = name_0()
# Out:
# Hello I am sravani

# %%
f0

# %%
f1 = name_1()

# %%
f1
# Out:
# 'Hellp I am sravani'

# %%
def greet(name):
    return f"Hello I am {name}"

# %%
greet("sai")
# Out:
# 'Hello I am sai'

# %%
greet("Balu")
# Out:
# 'Hello I am Balu'

# %%
def add(x=3,y=4):
    result = x + y
    return result

# %%
res = add(5,9)
res
# Out:
# 14
