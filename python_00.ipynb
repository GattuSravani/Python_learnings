# %%
x = [1, "sai",(8,3),{"name":'Sravs'}]
x
# Out:
# [1, 'sai', (8, 3), {'name': 'Sravs'}]

# %%
type(x)
# Out:
# list

# %%
x[3].keys()
# Out:
# dict_keys(['name'])

# %%
s = {3,6,9}
s
# Out:
# {3, 6, 9}

# %%
s
# Out:
# {3, 6, 9}

# %%
type(s)
# Out:
# set

# %%
l = list(s)
l
if 9 in l:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
x = 2

# %%
y = 3
x == y
# Out:
# False

# %%
l = [1,2,3,6,4]

l
# Out:
# [1, 2, 3, 6, 4]

# %%
a = range(0,9)
a
# Out:
# range(0, 9)

# %%
type(a)
# Out:
# range

# %%
l = [98,5,21,8,6,13,43,33,65]
for i in range(0,len(l)): # i = 5
    if l[i]%2 == 0:
        l[i] = 100

# %%
l
# Out:
# [100, 5, 21, 100, 100, 13, 43, 33, 65]

# %%
l = [98,5,21,8,6,13,43,33,65]
m = []
for i in range(len(l)):
    if l[i]%2 == 0:
        m.append(l[i])
print(m)
# Out:
# [98, 8, 6]

# %%
l = [98,5,21,8,6,13,43,33,65]
m = []
for i in l:  # i = 8
    if i%2 == 0:
        m.append(i)
m
# Out:
# [98, 8, 6]

# %%
l = [98,5,21,8,6,13,43,33,65]
m = [i for i in l if i%2==0]
m
# Out:
# [98, 8, 6]

# %%
l = [98,5,21,8,6,13,43,33,65]
m = [l[i] for i in range(len(l)) if l[i]%2==0]
m
# Out:
# [98, 8, 6]

# %%
m = [i if i%2 == 0 else 1 for i in l]
m
# Out:
# [98, 1, 1, 8, 6, 1, 1, 1, 1]

# %%
m = [l[i] if l[i]%2 == 0 else 1000 for i in range(len(l))]
m
# Out:
# [98, 1000, 1000, 8, 6, 1000, 1000, 1000, 1000]

# %%
s = 'sai'
for i in s:
    print(i)
# Out:
# s
# a
# i

# %%
price = 59
txt = f"The price is {price:.5f} dollars"
print(txt)
# Out:
# The price is 59.00000 dollars

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[2] = "purpul"
print(thislist)
# Out:
# ['apple', 'banana', 'purpul']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
r = [10,20,30,40,50]
r.append(100)
r
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
r = [10,20,30,40,50]
r.insert(1,100)
r
# Out:
# [10, 100, 20, 30, 40, 50]

# %%
r1 = [10,20,30,40,50]
r2 = [100,200,300,400,500]
r1.extend(r2)
r1
# Out:
# [10, 20, 30, 40, 50, 100, 200, 300, 400, 500]

# %%
r = [10,20,30,40,50]
r.pop(1)#pop():-->last element will remove
r

# %%
r = [10,20,30,40,50]
del r[1]
r
# Out:
# [10, 30, 40, 50]

# %%
r = [10,20,30,40,50]
r.clear()
r
# Out:
# []

# %%
r = [10,15,20,25,30,35,40,45,50]
for i in range(len(r)):
    print(r[i])
# Out:
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
f1 = [10, 20, 30]
i = 0
while i < len(f1):
  print(f1[i])
  i = i + 1
# Out:
# 10
# 20
# 30

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
n1 = [2,19,78]
l = [2 for x in n1]

# %%
fruits = ['apple', 'banana', 'cherry']
newlist = ['apple' for x in fruits]

# %%
r = [10,1,54,434,20,3234,30,34,402,34,50]
r.sort()
r
# Out:
# [1, 10, 20, 30, 34, 34, 50, 54, 402, 434, 3234]

# %%
r = [10,1,54,434,20,3234,30,34,402,34,50]
r.sort(reverse=True)
r
# Out:
# [3234, 434, 402, 54, 50, 34, 34, 30, 20, 10, 1]

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
def n1(s):
    return abs(s-50)
t1=[93,43,56,24,76]
t1.sort(key=n1)
t1
# Out:
# [56, 43, 24, 76, 93]

# %%
r = [10,1,54,434,20,3234,30,34,402,34,50]
r.reverse()
r
# Out:
# [50, 34, 402, 34, 30, 3234, 20, 434, 54, 1, 10]

# %%
l1=(3,45,3,23,234,535,67876,345)
l2=(1000,)
l1+=l2
l1
# Out:
# (3, 45, 3, 23, 234, 535, 67876, 345, 1000)

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)

print(thistuple)
# Out:
# ('banana', 'cherry')

# %%
l1=(3,45,3,23,234,535,67876,345)
l2=list(l1)
l2.remove(23)
l1=tuple(l2)
l1
# Out:
# (3, 45, 3, 234, 535, 67876, 345)

# %%
thisset = set(("apple", "banana", "cherry")) 
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'banana', 'orange', 'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'banana', 'orange', 'apple', 'cherry'}

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict.keys()
print(x)
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict.values()
print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict.items()
print(x)
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.items()

print(x) 

car["color"] = "red"
car["price"] = 2500000

print(x)
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'red'), ('price', 2500000)])

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "color": "red"
}
thisdict.update({"year": 2020})
thisdict.update({"color": "pink"})
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020, 'color': 'pink'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "color": "red"
}
thisdict.update({"year": 2020})
thisdict.pop("color")
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "color": "red"
}
thisdict.update({"year": 2020})
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "color": "red"
}
thisdict.update({"year": 2020})
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
dictionary.update(iterable)
