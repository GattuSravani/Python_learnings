# %%
l1 = ["sai", 24, "sravani","Balu","Kumari",1,"32"]
l2 = []
l3 = []

for i in l1:
    if type(i) == int:
        l2.append(i)
    else:
        l3.append(i)
print(l2)
l3
# Out:
# [24, 1]
# ['sai', 'sravani', 'Balu', 'Kumari', '32']

# %%
l4 = [i for i in l1 if type(i) == int]
print(l4)
l5 = [i for i in l1 if type(i) == str]
print(l5)
# Out:
# [24, 1]
# ['sai', 'sravani', 'Balu', 'Kumari', '32']

# %%
l1 = ["sai", 24, "sravani","Balu","Kumari",1,"32"]
l2 = []
l3 = []
for i in range(len(l1)):
    if type(l1[i]) == int :
        l2.append(l1[i])
    else:
        l3.append(l1[i])

print(l2)
print(l3)
# Out:
# [24, 1]
# ['sai', 'sravani', 'Balu', 'Kumari', '32']

# %%
l1 = ["sai", 24, "sravani","Balu","Kumari",1,"32"]
l2 = []
l3 = []
for i in range(len(l1)):
    if type(l1[i]) == int:
        if l1[i]%2 == 0:
           l2.append(l1[i])
    else:
        l3.append(l1[i])
print(l2)
print(l3)
# Out:
# [24]
# ['sai', 'sravani', 'Balu', 'Kumari', '32']

# %%
l1 = [3,2,3,2,1,1,7,5,7,5,9,0,4]
l2 = set(l1)
l3 = list(l2)
l3
# Out:
# [0, 1, 2, 3, 4, 5, 7, 9]
